# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd

# %%
print("np.__version__", np.__version__)
print("pd.__version__", pd.__version__)
print("OK")
# Out:
# np.__version__ 2.4.0
# pd.__version__ 2.3.3
# OK

# %%
test_list = [7, 8, 4, 5, 1, 9, 2, 3, 6]
df =  pd.array(test_list)
print(df)
# Out:
# <IntegerArray>
# [7, 8, 4, 5, 1, 9, 2, 3, 6]
# Length: 9, dtype: Int64

# %%
print(df.max())
print(df.mean())
print(df.min())
# Out:
# 9
# 5.0
# 1
